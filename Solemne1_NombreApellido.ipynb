# %% [markdown]
# # ENCARGO UNIDAD 1
#
#
#
#
# ---
#
#
# * Nombres:
#     <ul>
#             <li> Alexis Alfaro Andrade </li>
#             <li> Jefersson Muñoz Zapata </li>
#     </ul>

# %% [markdown]
# # Sección 1 - Análisis exploratorio
#
#
# A continuación, tendrás que interpretar la información de un dataset en Python.
#
#
# ---
#
# Comencemos con un clásico dentro del mundo de data science. Trabajaremos con **Iris**. Un dataset muy conocido en la academia, que sirve bastante para comenzar dentro del mundo del Data Science.
# Antes de comenzar, demos contexto a todo esto. Iris es un dataset que nos permite clasificar flores a partir de características que poseen las plantas.
#
# Las características o features son las siguientes:
#
# * sepal lenght o largo del sépalo en cm,
#
# * sepal width o ancho del sépalo en cm,
#
# * petal lenth o largo del pétalo en cm,
#
# * petal width o ancho del pétalo en cm.
#
#
# Las diferentes especies a las que puede pertenecer una planta son:
#
# *   Setosa
# *   Virginica
# *   Versicolor

# %% [markdown]
# ![1_Hh53mOF4Xy4eORjLilKOwA.png](data:image/png;base64,...)

# %%
#Cargamos las librerías de Python que nos servirán para todo esto
import numpy as np
import pandas as pd

# %%
#Cargamos el dataset de Iris para comenzar a trabajarlo

#Puedes cargarlo desde la librería Scikit-learn
from sklearn.datasets import load_iris

data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = data['target']

# %%
#Si el recurso lo tienes de forma local y trabajas desde Anaconda entonces añade la ruta del archivo, y ejecuta este bloque

# data = pd.read_csv("your path dataset location")

# %%
#Si el recurso lo tienes en drive, puedes montar tu google Drive y hacer referencia a la ruta del dataset en el siguiente código

#from google.colab import drive
#drive.mount('/content/drive')
 
#df = pd.read_csv('/content/drive/MyDrive/rutaDrive', sep=",")

# %% [markdown]
# ##Instrucciones iniciales de python

# %%
#Utilice el comando head
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
#
# Con el comando head nos entrega la informacion del dataset es decir el nombre de las columnas(features,variables) con sus respectivos datos(observaciones), si solo utilizamos .head() nos entrega la informacion detallada de las primeras 5 filas del dataset.

# %%
#Utilice tail
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
# Nos entrega la informacion detallada de los ultimas 5 filas del dataset en el cual nos entrega la informacion del dataset es decir el nombre de cada columna con sus datos correspondientes de cada columna.

# %%
#Utilice sample 
df.sample()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 53                5.5               2.3                4.0               1.3
#
#     target
# 53       1

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
#
# Al utilizar el comando sample() nos devuelve una muestra aleatoria es decir nos muestra una fila aleatoria con sus respectivas observaciones en cada columna.

# %%
#utilice columns
df.columns
# Out:
# Index(['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)',
#        'petal width (cm)', 'target'],
#       dtype='object')

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
#
# Con el comando columns nos entregera el nombre de cada columna del dataset o mejor dicho nos entrega las etiquetas de columna del dataset.

# %%
#Utilice mean, mode and median
#Forma 1 Mean
df.mean()
# Out:
# sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# target               1.000000
# dtype: float64

# %%
#Forma 1 Mode
df.mode()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.0               3.0                1.4               0.2
# 1                NaN               NaN                1.5               NaN
# 2                NaN               NaN                NaN               NaN
#
#    target
# 0       0
# 1       1
# 2       2

# %%
#Forma 1 Median
df.median()
# Out:
# sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# target               1.00
# dtype: float64

# %%
#Forma 2 de utilizar mean, mode and median

print("MEAN\n",df.mean(),"\n")
print("MODE\n",df.mode(),"\n")
print("MEDIAN\n",df.median(),"\n")
# Out:
# MEAN
#  sepal length (cm)    5.843333
# sepal width (cm)     3.057333
# petal length (cm)    3.758000
# petal width (cm)     1.199333
# target               1.000000
# dtype: float64
#
# MODE
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.0               3.0                1.4               0.2
# 1                NaN               NaN                1.5               NaN
# 2                NaN               NaN                NaN               NaN
#
#    target
# 0       0
# 1       1
# 2       2
#
# MEDIAN
#  sepal length (cm)    5.80
# sepal width (cm)     3.00
# petal length (cm)    4.35
# petal width (cm)     1.30
# target               1.00
# dtype: float64

# %%
#Forma 3 de calcular el mean, mode and median
for feature in df.columns:
    print('El promedio de', feature, '=', df[feature].mean())
    print('La moda de', feature, '=', df[feature].mode())
    print('La mediana de', feature, '=', df[feature].median(),"\n")
# Out:
# El promedio de sepal length (cm) = 5.843333333333335
# La moda de sepal length (cm) = 0    5.0
# dtype: float64
# La mediana de sepal length (cm) = 5.8
#
# El promedio de sepal width (cm) = 3.057333333333334
# La moda de sepal width (cm) = 0    3.0
# dtype: float64
# La mediana de sepal width (cm) = 3.0
#
# El promedio de petal length (cm) = 3.7580000000000027
# La moda de petal length (cm) = 0    1.4
# 1    1.5
# dtype: float64
# La mediana de petal length (cm) = 4.35
#
# El promedio de petal width (cm) = 1.199333333333334
# La moda de petal width (cm) = 0    0.2
# dtype: float64
# La mediana de petal width (cm) = 1.3
#
# El promedio de target = 1.0
# La moda de target = 0    0
# 1    1
# 2    2
# dtype: int32
# La mediana de target = 1.0

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
#
# El comando mean() nos sirve para calcular el promedio los datos de cada columna, el comando mode nos sirve para calcular la moda de los datos de cada columna es decir cual o cuales son los datos que mas se repiten y por ultimo el comando median nos entrega la mediana de los datos de cada columna. Los resultados obtenidos fueron los siguientes:
#
# El promedio de sepal length (cm) = 5.843333333333335
# La moda de sepal length (cm) = 0    5.0
# dtype: float64
# La mediana de sepal length (cm) = 5.8
#
# El promedio de sepal width (cm) = 3.057333333333334
# La moda de sepal width (cm) = 0    3.0
# dtype: float64
# La mediana de sepal width (cm) = 3.0
#
# El promedio de petal length (cm) = 3.7580000000000027
# La moda de petal length (cm) = 0    1.4
# 1    1.5
# dtype: float64
# La mediana de petal length (cm) = 4.35
#
# El promedio de petal width (cm) = 1.199333333333334
# La moda de petal width (cm) = 0    0.2
# dtype: float64
# La mediana de petal width (cm) = 1.3
#
# El promedio de target = 1.0
# La moda de target = 0    0
# 1    1
# 2    2
# dtype: int32
# La mediana de target = 1.0
#
# Con las observaciones anteriores se puede observar que la columna que tiene mayor promedio es la de sepal length (cm) asi como tambien es la que presenta mayor mediana.Podemos observar que en la moda de petal length (cm) tenemos 2 valores que se repiten mas en cuanto al largo del petalo los cuales son 1.4 y 1.5.Tambien podemos observar que en la moda de target nos sale 3 valores que se repiten mas los cuales son 0,1 y 2, eso esta bien puesto que los tipos de clasificacion estan distribuidos de manera uniforme es decir 50 para tipo 0, 50 para tipo 1 y 50 para tipo 2.

# %%
#Utilizamos value_counts()
df.value_counts()
#df.groupby(['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']).size()
# Out:
# sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  target
# 5.8                2.7               5.1                1.9               2         2
# 7.9                3.8               6.4                2.0               2         1
# 5.4                3.0               4.5                1.5               1         1
# 5.5                2.4               3.7                1.0               1         1
#                    2.3               4.0                1.3               1         1
#                                                                                    ..
# 6.3                2.5               4.9                1.5               1         1
#                    2.3               4.4                1.3               1         1
# 6.2                3.4               5.4                2.3               2         1
#                    2.9               4.3                1.3               1         1
# ...

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
# Con el comando value_counts() nos entregará la información de cuantos valores unicos hay en el datasety los mostrara en orden descendente de modo que el primer el elemento sea el elemento que se presente con mayor frecuencia es decir cuantos valores unicos hay que contenga las siguientes columnas : sepal length (cm), sepal width (cm) ,petal length(cm),petal width (cm),target.Hara un recuento de los valores unicos y los mostrara de mayor a menor. En resumen el comando value_counts() nos entrega el total de observaciones en relacion a todas las columnas.

# %%
#Utilizamos describe()
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
#
# La función anterior obtiene las estadísticas de 5 columnas las cuales todas son columnas numericas.
#
# El comando describe nos ayudara con las estadisticas descriptivas de cada columna la cual incluye la cantidad de los datos(count), el promedio de los datos(mean), la desviacion de los datos(std), el valor minimo de los datos(min), el 25% de los datos(25%), el 50% de los datos(50%) que corresponderia a la mediana de los datos, el 75% de los datos(75%) y por ultimo nos entrega cual es el valor maximo de los datos(max).
#
# La interpretación (considerando la columa sepal length (cm)):
# 1. Hay 150 valores en la columna
# 2. El promedio corresponde a 5.84
# 3. La desviación estándar es de 0.83, lo que quiere decir, la sepal length (cm) de las observaciones varía dentro del intervalo [5.01, 6.67] [mean - std; mean + std]
# 4. Valor mínimo de la columna es 4.3
# 5. El 25% de las observaciones es menor a 5.1
# 6. El 50% de las observaciones es menor a 5.8
# 7. El 75% de las observaciones es menor a 6.4
# 8. El valor máximo de la columna es 7.9

# %%
#Utilizamos info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int32
# dtypes: float64(4), int32(1)
# memory usage: 5.4 KB

# %% [markdown]
# Añadir qué observaciones hay respecto del comando utilizado
#
# El comando info() imprime información sobre el dataset , incluyendo, el numero de columna con su nombre correspondiente, los valores no nulos y el tipo de dato de la columna correspondiente y el uso de la memoria.
#
# La interpretación (considerando la columa petal length (cm)): + Es la tercera columna + Tiene 150 valores no nulos + Son de tipo float64
#
# Ademas los tipos de datos presentados en la columnas fueron de tipo float64(4) es decir 4 columnas son de tipo float64 y una columna es de tipo int32(1)
#
# El uso de memoria es de 5.4 KB

# %%
#Otra forma de ver los valores nulos
for feature in df.columns:
    print("Total de valores nulos de",feature,'=',df[feature].isna().sum())
# Out:
# Total de valores nulos de sepal length (cm) = 0
# Total de valores nulos de sepal width (cm) = 0
# Total de valores nulos de petal length (cm) = 0
# Total de valores nulos de petal width (cm) = 0
# Total de valores nulos de target = 0

# %%
#Ver tamaño del dataset
df.shape
# Out:
# (150, 5)

# %%
df.target.value_counts()
# Out:
# 2    50
# 1    50
# 0    50
# Name: target, dtype: int64

# %% [markdown]
# ##Gráficos
# Plantear algunos gráficos que le ayuden a explorar de mejor manera y genérelos con su respectivo análisis

# %%
#Importación de las librerias a utilizar para los respectivos calculos y graficos
from sklearn import datasets,linear_model
from sklearn import model_selection
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sb
from sklearn.metrics import confusion_matrix,precision_score, accuracy_score, recall_score, classification_report

# %% [markdown]
# # Mapas de calor

# %%
plt.figure(figsize=(10, 5))
p = sb.heatmap(df.corr(method='pearson'), annot=True, cmap='RdYlGn', square=True)

# %% [markdown]
# <h4> Observaciones </h4>
#
# La columna sepal width (cm) presenta una correlación negativa con respecto a target.Ademas las columnas petal length (cm) y petal width (cm) son las que presentan una mayor correlación positiva con respecto a target con 0.95 y 0.96 respectivamente que por cierto presentan una asociación muy alta con respecto a target. Mientras que sepal length (cm) presenta una correlacion positiva de 0.78 que a la vez presenta tiene asociación alta con respecto a target.

# %% [markdown]
# # Gráficos de distribución

# %%
df.drop(['target'],1).hist()
plt.show()

# %% [markdown]
# # Gráficos de distribución de forma individual

# %%
df['sepal length (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['sepal width (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['petal length (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['petal width (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['target'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %% [markdown]
# # Gráficos de dispersión

# %%
# Graficamos los datos correspondientes
plt.scatter(df['sepal length (cm)'], df['target'])
plt.xlabel('sepal length (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
# Graficamos los datos correspondientes
plt.scatter(df['sepal width (cm)'], df['target'])
plt.xlabel('sepal width (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
# Graficamos los datos correspondientes
plt.scatter(df['petal length (cm)'], df['target'])
plt.xlabel('petal length (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
# Graficamos los datos correspondientes
plt.scatter(df['petal width (cm)'], df['target'])
plt.xlabel('petal width (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %% [markdown]
# # Aplicaremos el modelo de regresion lineal logística antes de realizar la limpieza de datos

# %%
x = np.array(df.drop(['target'],1))
y = np.array(df['target'])
x.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %% [markdown]
# ## Transformación

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=29)

# %%
#Se escalan todos los datos
escalar = StandardScaler()
x_train = escalar.fit_transform(x_train)
x_test = escalar.transform(x_test)

# %%
model = linear_model.LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
print('Score del modelo (train): %.2f' % model.score(x_train, y_train)) 
print('Score del modelo (test): %.2f' % model.score(x_test, y_test))
# Out:
# Score del modelo (train): 0.97
# Score del modelo (test): 0.93

# %% [markdown]
# <h4> Observaciones </h4>

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 4  0  0]
#  [ 0 10  0]
#  [ 0  2 14]]

# %%
y_test.shape
# Out:
# (30,)

# %% [markdown]
# <h4> Observaciones </h4>
#
# Al tomar como prueba 30 valores en el entrenamiento del modelo de regresión logística nos dio como resultado 28 valores correctos es decir que de 4 que debian ser tipo Setosa los 4 estan correctos, que de 10 que debian ser de tipo Virginica los 10 estan correctos y  que de los 14 que deberian ser de tipo Versicolor 12 estaban correctos y 2 eran de tipo Virginica.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       0.83      1.00      0.91        10
#            2       1.00      0.88      0.93        16
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.96      0.95        30
# weighted avg       0.94      0.93      0.93        30

# %% [markdown]
# <h4> Observaciones </h4>
#
# Se puede observar que las columnas de tipo 0 y 2 presentan una presicion exacta de 1 mientras que la columna de tipo 1 presenta una menor presicion de 0.83.

# %% [markdown]
# # Ver outliers

# %%
#Boxplot forma 1
for i in range(len(df.columns)):
    sb.boxplot(df.iloc[:,i])
    plt.show()
# Out:
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# <h4> Observaciones </h4>

# %% [markdown]
# # Gráficos de los outliers encontrados

# %%
sb.boxplot(df['sepal width (cm)'])
plt.show()
# Out:
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_values = df['sepal width (cm)'].unique()
y_values = df['sepal width (cm)'].value_counts().tolist()
plt.scatter(x_values,y_values,marker='o')
plt.title('Distribucion Sepal width')
plt.xlabel('Sepal width')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# # Cálculos del cuartil para las columnas que tiene outliers en este caso son: sepal width (cm)

# %%
print("Sepal width (cm)\n")
Q1_sepal_width =df['sepal width (cm)'].quantile(0.25)
print("Primer cuartil",Q1_sepal_width)
Q3_sepal_width = df['sepal width (cm)'].quantile(0.75)
print("Tercer cuartil",Q3_sepal_width)

IQR_sepal_width = Q3_sepal_width-Q1_sepal_width
print("Rango intercuartil",IQR_sepal_width)

Mediana_sepal_width = df['sepal width (cm)'].median()
print("La mediana es :",Mediana_sepal_width)
Valor_minimo_sepal_width = df['sepal width (cm)'].min()
print("Valor minimo :",Valor_minimo_sepal_width)
Valor_maximo_sepal_width = df['sepal width (cm)'].max()
print("Valor maximo es :",Valor_maximo_sepal_width)

#Calculamos los valores de los bigotes inferior y superior
BI_Calculado_sepal_width = (Q1_sepal_width - 1.5 * IQR_sepal_width)
print("BI Calculado:",BI_Calculado_sepal_width)

BS_Calculado_sepal_width = (Q3_sepal_width + 1.5 * IQR_sepal_width)
print("BS Calcular:",BS_Calculado_sepal_width)
# Out:
# Sepal width (cm)
#
# Primer cuartil 2.8
# Tercer cuartil 3.3
# Rango intercuartil 0.5
# La mediana es : 3.0
# Valor minimo : 2.0
# Valor maximo es : 4.4
# BI Calculado: 2.05
# BS Calcular: 4.05

# %% [markdown]
# # Limpieza de datos
# <h5> Una vez ya identificados los outliers procedemos a realizar la limpieza correspondiente de cada columna que presente outliers </h5>

# %%
df = df.drop(df[df['sepal width (cm)'] >= 4.05].index)

# %%
df = df.drop(df[df['sepal width (cm)'] <= 2.05].index)

# %% [markdown]
# # Volvemos a graficar las columnas que presentaron outliers para ver si ya no tienen outliers

# %%
sb.boxplot(df['sepal width (cm)'])
plt.show()
# Out:
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# <h4> Observaciones </h4>
# Se puede observar que los outliers de la columna sepal width (cm) han sido limpiados de manera exitosa

# %%
x_values = df['sepal width (cm)'].unique()
y_values = df['sepal width (cm)'].value_counts().tolist()
plt.scatter(x_values,y_values,marker='o')
plt.title('Distribucion Sepal width')
plt.xlabel('Sepal width')
plt.ylabel('Cantidad')
plt.show()

# %% [markdown]
# # Por último se procede a realizar los gráficos boxplot para revisar si todas las columnas ya no presentan outliers

# %%
#Boxplot forma 1
for i in range(len(df.columns)):
    sb.boxplot(df.iloc[:,i])
    plt.show()
# Out:
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Alumno\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %% [markdown]
# <h4> Observacione </h4>
# Se puede observar que ninguna columna presenta outliers por ende se procederá a revisar que paso con las estadisticas y los gráficos una vez realizada la limpieza de datos de la columna sepal width (cm). Para asi proceder a realizar el entrenamiento del modelo correspondiente.

# %% [markdown]
# # Volveremos a revisar las estadisticas y los diferentes gráficos para ver si tuvieron alguna variacion

# %%
df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         146.000000        146.000000         146.000000
# mean            5.856849          3.040411           3.806849
# std             0.834093          0.397853           1.758042
# min             4.300000          2.200000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.400000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.000000           6.900000
#
#        petal width (cm)      target
# count        146.000000  146.000000
# mean           1.220548    1.020548
# std            0.759393    0.817643
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %% [markdown]
# <h4> Observacione </h4>
# Se observar que la cantidad de los datos ha variado paso de tener 150 muestras a tener 46 muestras.
#
# La interpretación (considerando la columa sepal length (cm)):
# 1. Hay 146 valores en la columna antes se tenia 150 muestras
# 2. El promedio corresponde a 5.86 es decir aumento 0.02 ya que antes se tenia 5.84
# 3. La desviación estándar es de 0.83, lo que quiere decir, la sepal length (cm) de las observaciones varía dentro del intervalo [5.03 , 6.69] [mean - std; mean + std] por ende tambien vario en 0.02 el intervalo ya que antes se tenia [5.01 , 6.67)
# 4. Valor mínimo de la columna es 4.3
# 5. El 25% de las observaciones es menor a 5.1
# 6. El 50% de las observaciones es menor a 5.8
# 7. El 75% de las observaciones es menor a 6.4
# 8. El valor máximo de la columna es 7.9
#
# El valor mínimo, el 25%, el 50%, el 75% y el max no sufrieron alguna variación.

# %%
df.groupby('target').size()
# Out:
# target
# 0    47
# 1    49
# 2    50
# dtype: int64

# %% [markdown]
# <h4> Observaciones </h4>
# La distribución de los datos cambio paso de tener una distribución uniforme a tener 47 datos de tipo Setosa, 49 de tipo Virginica y 50 de tipo Versicolor.

# %% [markdown]
# # Mapas de calor

# %%
plt.figure(figsize=(10, 5))
p = sb.heatmap(df.corr(method='pearson'), annot=True, cmap='RdYlGn', square=True)

# %% [markdown]
# <h4> Observaciones </h4>
#
# La columna sepal length (cm) sufrió una ligera variacion ya que paso de tener 0.78 de correlacion a tener 0.79 es decir aumento en 0.01, lo mismo pasa con la columna sepal width (cm) que paso de tener una correlacion de -0.43 a -0.41 es decir aumento en 0.02.

# %% [markdown]
# # Gráficos de distribución de forma individual

# %%
df['sepal length (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['sepal width (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['petal length (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['petal width (cm)'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
df['target'].hist()
plt.title("Sepal Lenght (cm)")
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %% [markdown]
# # Gráficos de dispersión

# %%
# Graficamos los datos correspondientes
plt.scatter(df['sepal length (cm)'], df['target'])
plt.xlabel('sepal length (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
# Graficamos los datos correspondientes
plt.scatter(df['sepal width (cm)'], df['target'])
plt.xlabel('sepal width (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
# Graficamos los datos correspondientes
plt.scatter(df['petal length (cm)'], df['target'])
plt.xlabel('petal length (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %%
# Graficamos los datos correspondientes
plt.scatter(df['petal width (cm)'], df['target'])
plt.xlabel('petal width (cm)')
plt.ylabel('target')
plt.show()

# %% [markdown]
# <h4> Observaciones </h4>

# %% [markdown]
# # Aplicaremos el modelo de regresion lineal logística despues de hacer la limpieza correspondiente

# %%
x = np.array(df.drop(['target'],1))
y = np.array(df['target'])
x.shape
# Out:
# (146, 4)

# %%
y.shape
# Out:
# (146,)

# %% [markdown]
# ## Transformación

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=29)

# %%
#Se escalan todos los datos
escalar = StandardScaler()
x_train = escalar.fit_transform(x_train)
x_test = escalar.transform(x_test)

# %%
model = linear_model.LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
print('Score del modelo (train): %.2f' % model.score(x_train, y_train)) 
print('Score del modelo (test): %.2f' % model.score(x_test, y_test))
# Out:
# Score del modelo (train): 0.97
# Score del modelo (test): 0.93

# %% [markdown]
# <h4> Observaciones </h4>

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.9333333333333333

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 7  0  0]
#  [ 0  9  1]
#  [ 0  1 12]]

# %%
y_test.shape
# Out:
# (30,)

# %% [markdown]
# <h4> Observaciones </h4>
# Despues de realizar la limpieza de datos como ya no se tiene una distribución uniforme de los datos al tomar como prueba 30 valores en el entrenamiento del modelo de regresión logística nos dio como resultado 28 valores correctos es decir que de 7 que debian ser tipo Setosa los 7 estan correctos, que de 10 que debian ser de tipo Virginica 9 solo estaban correctas y ese 1 es de tipo Versicolor, que de los 13 que deberian ser de tipo Versicolor 12 estaban correctos y 1 era de tipo Virginica.

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         7
#            1       0.90      0.90      0.90        10
#            2       0.92      0.92      0.92        13
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.94        30
# weighted avg       0.93      0.93      0.93        30

# %% [markdown]
# <h4> Observaciones </h4>
# Se puede observar que el tipo Setosa tuvo la mejor precision ya que tuvo una precisión exacta de 1 y la que tuvo una menor precisión fue la del tipo Virginica que presentó una precisión de 0.90

# %% [markdown]
# ##Responder
# Conteste las siguientes preguntas respecto al dataset explorado

# %% [markdown]
# A. ¿Cuál es la cantidad de registros que tiene el dataset?
#
# R: El dataset cuenta con 150 registros de los cuales estan distribuidos en 5 columnas y 150 filas es decir 150 observaciones por cada columna.

# %% [markdown]
# B. ¿Cuál es el promedio de los anchos y los largos de pétalo que hay en la muestra?
#
# R:El promedio antes de realizar la limpieza correspondiente de los anchos de petalo  : 1.199333 y el promedio de los largos del petalo es: 3.758000
#
# El promedio despues de realizar la limpieza correspondiente de los anchos de petalo  : 1.220548 y el promedio de los largos del petalo es: 3.806849

# %% [markdown]
# C. ¿Hay registros nulls dentro de la data? ¿Cómo se dió cuenta?
#
# R: No, no hay registros nulls dentro de la data y nos pudimos dar cuenta porque ocupamos el metodo .info() es decir df.info() en la cual nos dice cuantos valores no nulls existen ademas de brindarnos el tipo de dato. Para comprobar si la infomacion que nos entro .info es correcta, vamos a verificarlo con el siguiente procedimiento : "for feature in df.columns:print("Valores nulos de",feature,'=',df[feature].isna().sum())". Al correr ese codigo nos da como resultado 0 en todas las columnas es decir que no hay valores nulls en ninguna columna.

# %% [markdown]
# D. En Machine Learning se habla mucho de aprendizaje supervisado y no supervisado. Uno tiene etiqueta y el otro no tiene etiqueta respectivamente. ¿Qué tipo de aprendizaje cree que correspondería utilizar?¿Por qué?
#
# R:Corresponderia a utilizar el aprendizaje supervisado. En esta modalidad se podría entender como algoritmos que “aprenden” de los datos introducidos por una persona. En este caso:
#
# Se necesita la intervención humana para etiquetar, clasificar e introducir los datos en el algoritmo. El algoritmo genera datos de salida esperados, ya que en la entrada han sido etiquetados y clasificados por alguien. Existen dos tipos de datos que pueden ser introducidos en el algoritmo: Clasificación: clasifican un objeto dentro de diversas clases. Por ejemplo, para determinar si un paciente está enfermo o si un correo electrónico es spam. Regresión: predicen un valor numérico. Sería el caso de los precios de una casa al escoger diferentes opciones o la demanda de ocupación de un hotel. Algunas aplicaciones prácticas de este tipo de Machine Learning: La predicción de coste de un siniestro en el caso de las compañías de seguros. La detección de fraude bancario por parte de entidades financieras. La previsión de avería en la maquinaria de una compañía.

# %% [markdown]
# E. ¿Cómo están distribuídos los datos dentro de la muestra respecto de las especies?. En caso de tener más ejemplos de un tipo de flor, y menos de otro tipo ¿crees que influiría en el algoritmo final? ¿por qué?
#
# R:
# Antes de realizar la limpieza correspondiente los datos estan distribuidos de manera uniforme es decir de 150 muestras 50 son de tipo Setosa, 50 de tipo Virginica y 50 de tipo Versicolor. Una vez realizada la limpieza de datos la distribución de los datos cambió puesto que ahora solo existen 146 muestras de los cuales 47 muestras son de tipo Setosa por lo tanto paso de tener 50 muestras a 47 muestras es decir perdió 3 muestras , 49 son de tipo Virginica por lo tanto paso de tener 50 muestras a 49 muestras es decir perdió 1 muestra y 50 de tipo Versicolor por ende de los 3 tipos fue la unica que no presentó cambio en sus muestras.
#
# Y si influiria tener mas ejemplos de un tipo de flor que de otro puesto que la precisión de los datos cambia. Para ello realizamos el entrenamiento de modelo antes de realizar la limpieza de datos en donde la distribucion de datos era de manera uniforme y luego realizamos otro entrenamiento del modelo con la limpieza de datos realizadas en la cual la distribucion ya no era de manera uniforme es decir que existian mas muestras de un tipo de que otra y las observaciones fueron las siguientes:
#
# - Antes de realizar la limpieza de datos nos dieron los siguientes resultados:
#
# Al tomar como prueba 30 valores en el entrenamiento del modelo de regresión logística nos dio como resultado 28 valores correctos es decir que de 4 que debian ser tipo Setosa los 4 estan correctos, que de 10 que debian ser de tipo Virginica los 10 estan correctos y  que de los 14 que deberian ser de tipo Versicolor 12 estaban correctos y 2 eran de tipo Virginica.  Ademas se tenia que las columnas de tipo Setosa y Versicolor presentaban una precision perfecta de 1.
#
# - Despues de realizar la limpieza de datos nos dieron los siguientes resultados:
#
# Despues de realizar la limpieza de datos como ya no se tiene una distribución uniforme de los datos al tomar como prueba 30 valores en el entrenamiento del modelo de regresión logística nos dio como resultado 28 valores correctos es decir que de 7 que debian ser tipo Setosa los 7 estan correctos, que de 10 que debian ser de tipo Virginica 9 solo estaban correctas y ese 1 es de tipo Versicolor, que de los 13 que deberian ser de tipo Versicolor 12 estaban correctos y 1 era de tipo Virginica. La precisión cambió ya que ahora solo Setosa tiene una precisión perfecta de 1 pero la precisión de tipo Virginica aumentó ya que antes tenia una precisión de 0.83 y aumentó a 0.90 mientras que la precisión de tipo Versicolor disminuyó a 0.92.

# %% [markdown]
# F. ¿Qué procesamiento podríamos hacer como rutina de limpieza?. Propone 3 acciones que se podrían efectuar a este dataset.
#
# R:
# <li> Se podria eliminar las observaciones (opción simple) </li>
# <li> Se podria realizar una imputación (mejor opción). Acá se rellenan los valores vacíos con algún valor, puede ser el promedio del valor de la columna. Puede ser el valor más repetido en el caso de una variable categórica. </li>
# <li> Se podria hacer una extensión de la imputación. Se agrega una columna indicando que el valor ha sido reemplazado, de esta forma, se mantiene "identificados" a los valores nulos </li>

# %% [markdown]
# G. Ingresa 3 descubrimientos adicionales a los ya contestados anteriormente, que complementen el análisis exploratorio que acabas de realizar sobre los datos.
#
# - Se encontraron outliers en la columna de sepa width (cm) a partir del grafico de boxplot, se procedió a encontrar el bigote superior e inferior de sepa width (cm) y luego se hizo la limpieza correspondiente.
# - Una vez realizada la limpieza de datos el promedio correspondiente a los anchos de petalo y largo del petalo cambiaron por ende sus nuevos valores son de: anchos de petalo  =  1.220548 y el promedio de los largos del petalo = 3.806849
# - Una vez realizada la limpieza de datos la distribución de los datos cambió puesto que ahora solo existen 146 muestras de los cuales 47 muestras son de tipo Setosa por lo tanto paso de tener 50 muestras a 47 muestras es decir perdió 3 muestras , 49 son de tipo Virginica por lo tanto paso de tener 50 muestras a 49 muestras es decir perdió 1 muestra y 50 de tipo Versicolor por ende de los 3 tipos fue la unica que no presentó cambio en sus muestras.
# - Se encontró una correlacion negativa en sepal width (cm) con respecto al target dando una proporcionalidad inversa es decir cuando una aumenta la otra disminuye.

# %% [markdown]
# # Sección 2 - Preprocesamiento
#
# Sobre el data ser Placement_Data_Full_Class.csv (Disponible en el repositorio) deberás plantear una rutina de limpieza de los datos y ejecutar esta rutina.
#
# Recuerda utilizar manejo de Missing Values, outliers, distribuciones, estadísticos, etc. Y a través de esto, ejecuta una rutina de limpieza y preprocesamiento utilizando los métodos vistos en la sesión.
#
# ¿Qué características te parece que son las más importantes? ¿Cuales no son significativas para la predicción de los salarios? ¿Descartarías alguna característica en particular utilizando la lógica o la intuición? ¿Por qué la/s descartaría/s?
#
# Para entender mejor el set de datos, se detalla a continuación lo que representa cada valor:
#
# sl_no: Serial Number - número de serie y del tipo entero
# gender: valor categórico que corresponde al género y toma los valores F o M
# ssc_p: puntaje de educación secundaria 10mo grado (%)
# ssc_b: junta de educación secundaria (central/otros)
# hsc_p: puntaje(%) de educación secundaria superior 12vo grado
# hsc_b: junta de educación superior (central/otros)
# hsc_s: especialización en educación secundaria superior
# degree_p: puntaje(%) de graduación
# degree_t: tipo de titulo - registro de graduación
# workex: Experiencia laboral
# etest_p: puntaje obtenido en la prueba de especialidad (%)
# specialisation: postgrado, especialización
# mba_p: (puntaje %) MBA
# status: estado de colocación colocado/no colocado
# salary: salario ofrecido por la empresa a los candidatos

# %% [markdown]
# # Sección 3 - Regresión
#
#
# A continuación, aplica un modelo de Regresión o de Clasificación al dataset de los Salarios en Python.
#
# ---
